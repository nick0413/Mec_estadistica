# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import os

# %%
files = os.listdir('positions1')
files = [file for file in files if file.endswith('.bin')]

with open('config1.txt','r') as f:
	lines = [float(line) for line in f.readlines()]



print(lines)
t_max_a = lines[0]
dt=lines[1]
V0=lines[2]
T=lines[3]
particle_postions_a = []
ii=0
N=len(files)
plt.figure(figsize=(18,8),dpi=200)
file=files[0]
	# check the file ends with .bin

ii+=1
x=np.fromfile('positions1/'+file,dtype=np.float64)
particle_postions_a.append(x)
hsv=((N-ii)/N,1,1)
time=np.linspace(0,t_max_a,len(x))

plt.plot(time,x,linewidth=0.4)
plt.xlim(xmin=-10)
plt.title("Posición como funcion del tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Posición")
plt.show()
# Out:
# [10000.0, 0.01, 10.0, 4.0, 1.0]

# %%
fig, ax = plt.subplots(ncols=2, gridspec_kw={'width_ratios': [1, 8]})
fig.set_dpi(200)
fig.set_size_inches(12, 5)
t_i=68

ax[0].scatter(0,x[t_i],color='red')
ax[1].plot(x[:t_i],linewidth=0.4)
ymin, ymax = ax[1].get_ylim()
increase=0.5
print(ymin,ymax)
ax[1].set_ylim(-increase+ymin,increase+ymax)
ax[0].set_ylim(-increase+ymin,increase+ymax)
ax[0].set_xticks([])
ax[1].set_yticks([])
ax[0].set_facecolor('c')
# ax[0].set_xlim(-1,1)
# Out:
# -0.1371947473899059 5.0534666201053255

# %%
plt.rcParams['text.color'] = 'w'
plt.rcParams['axes.labelcolor'] = 'w'
fig, ax = plt.subplots(ncols=2, gridspec_kw={'width_ratios': [1, 8]})
fig.patch.set_facecolor((14/255,29/255,57/255,255/255))
fig.set_dpi(300)
fig.set_size_inches(12, 5)
t_i=68
def update(t_i):
	ax[0].clear()
	ax[1].clear()
	ax[0].scatter(0,x[t_i],color='red')
	ax[1].plot(time[:t_i],x[:t_i],linewidth=4)
	ymin, ymax = ax[1].get_ylim()
	increase=0.5
	for spine in ax[0].spines.values():
		spine.set_edgecolor('w')
	for spine in ax[1].spines.values():
		spine.set_edgecolor('w')

	ax[0].tick_params(colors='w')
	ax[1].tick_params(colors='w')


	print(t_i)
	ax[1].set_ylim(-increase+ymin,increase+ymax)
	ax[0].set_ylim(-increase+ymin,increase+ymax)
	ax[0].set_xticks([])
	ax[1].set_yticks([])
	ax[0].set_facecolor('c')


ani = animation.FuncAnimation(fig, update, frames=np.arange(0,2000,10), interval=100)
ani.save("animacion.mp4", fps=30)
# Out:
# 0
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48
# 52
# 56
# 60
# 64
# 68
# 72
# 76
# 80
# 84
# 88
# 92
# 96
# 100
# 104
# 108
# 112
# 116
# 120
# 124
# 128
# 132
# 136
# 140
# 144
# 148
# 152
# 156
# 160
# 164
# 168
# 172
# 176
# 180
# 184
# 188
# 192
# 196
# 200
# 204
# 208
# 212
# 216
# 220
# 224
# 228
# 232
# 236
# 240
# 244
# 248
# 252
# 256
# 260
# 264
# 268
# 272
# 276
# 280
# 284
# 288
# 292
# 296
# 300
# 304
# 308
# 312
# 316
# 320
# 324
# 328
# 332
# 336
# 340
# 344
# 348
# 352
# 356
# 360
# 364
# 368
# 372
# 376
# 380
# 384
# 388
# 392
# 396
# 400
# 404
# 408
# 412
# 416
# 420
# 424
# 428
# 432
# 436
# 440
# 444
# 448
# 452
# 456
# 460
# 464
# 468
# 472
# 476
# 480
# 484
# 488
# 492
# 496
# 500
# 504
# 508
# 512
# 516
# 520
# 524
# 528
# 532
# 536
# 540
# 544
# 548
# 552
# 556
# 560
# 564
# 568
# 572
# 576
# 580
# 584
# 588
# 592
# 596
# 0
